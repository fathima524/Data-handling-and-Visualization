# %% [markdown]
# <a href="https://colab.research.google.com/github/fathima524/Data-handling-and-Visualization/blob/main/spatial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install folium

# %%
import folium

# Create a map centered around Cubbon Park
my_map = folium.Map(location=[12.9767, 77.5950], width=600, height=400, zoom_start=12, title="Cubbon park")

# Add a marker for Cubbon Park with a description
folium.Marker(location=[12.9767, 77.5950], popup="Cubbon Park", tooltip="A historic park in Bangalore").add_to(my_map)

# Add a marker for RT Nagar with a description and picture
rt_nagar_image_url = "data:image/jpeg;base64,..."
rt_nagar_description = "A residential area in Bangalore"
rt_nagar_tooltip_content = f"<a href='{rt_nagar_image_url}' target='_blank'><img src='{rt_nagar_image_url}' style='width:200px;height:200px;'></a> {rt_nagar_description}"
folium.Marker(location=[13.0237, 77.5954], popup="RT Nagar", tooltip=rt_nagar_tooltip_content).add_to(my_map)

# Add a marker for Church Street with a description and picture
church_street_image_url = "data:image/jpeg;base64,..."
church_street_description = "A popular street in Bangalore"
church_street_tooltip_content = f"<a href='{church_street_image_url}' target='_blank'><img src='{church_street_image_url}' style='width:200px;height:200px;'></a> {church_street_description}"
folium.Marker(location=[12.9748, 77.6059], popup="Church Street", tooltip=church_street_tooltip_content).add_to(my_map)

# Add a marker for Koramangala with a description and picture
koramangala_image_url = "data:image/jpeg;base64,..."
koramangala_description = "A vibrant neighborhood in Bangalore"
koramangala_tooltip_content = f"<a href='{koramangala_image_url}' target='_blank'><img src='{koramangala_image_url}' style='width:200px;height:200px;'></a> {koramangala_description}"
folium.Marker(location=[12.9352, 77.6245], popup="Koramangala", tooltip=koramangala_tooltip_content).add_to(my_map)

# Display the map with all markers
my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
# ...
